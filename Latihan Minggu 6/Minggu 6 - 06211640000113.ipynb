# %%
import pandas as pd
import numpy as np
data = pd.read_csv("weatherAUS.csv")
data
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0       2008-12-01   Albury     13.4     22.9       0.6          NaN
# 1       2008-12-02   Albury      7.4     25.1       0.0          NaN
# 2       2008-12-03   Albury     12.9     25.7       0.0          NaN
# 3       2008-12-04   Albury      9.2     28.0       0.0          NaN
# 4       2008-12-05   Albury     17.5     32.3       1.0          NaN
# 5       2008-12-06   Albury     14.6     29.7       0.2          NaN
# 6       2008-12-07   Albury     14.3     25.0       0.0          NaN
# 7       2008-12-08   Albury      7.7     26.7       0.0          NaN
# 8       2008-12-09   Albury      9.7     31.9       0.0          NaN
# 9       2008-12-10   Albury     13.1     30.1       1.4          NaN
# 10      2008-12-11   Albury     13.4     30.4       0.0          NaN
# 11      2008-12-12   Albury     15.9     21.7       2.2          NaN
# 12      2008-12-13   Albury     15.9     18.6      15.6          NaN
# ...

# %%
np.sum(data.isnull())
# Out:
# Date                 0
# Location             0
# MinTemp           1485
# MaxTemp           1261
# Rainfall          3261
# Evaporation      62790
# Sunshine         69835
# WindGustDir      10326
# WindGustSpeed    10263
# WindDir9am       10566
# WindDir3pm        4228
# WindSpeed9am      1767
# WindSpeed3pm      3062
# Humidity9am       2654
# Humidity3pm       4507
# Pressure9am      15065
# Pressure3pm      15028
# Cloud9am         55888
# Cloud3pm         59358
# Temp9am           1767
# Temp3pm           3609
# RainToday         3261
# RISK_MM           3267
# RainTomorrow      3267
# dtype: int64

# %%
from scipy import stats
data = data.drop(columns = ['Evaporation','Sunshine', 'Cloud9am', 'Cloud3pm'])

# %%
data.describe()
# Out:
#              MinTemp        MaxTemp       Rainfall  WindGustSpeed  \
# count  143975.000000  144199.000000  142199.000000  135197.000000
# mean       12.194034      23.221348       2.360918      40.035230
# std         6.398495       7.119049       8.478060      13.607062
# min        -8.500000      -4.800000       0.000000       6.000000
# 25%         7.600000      17.900000       0.000000      31.000000
# 50%        12.000000      22.600000       0.000000      39.000000
# 75%        16.900000      28.200000       0.800000      48.000000
# max        33.900000      48.100000     371.000000     135.000000
#
#         WindSpeed9am   WindSpeed3pm    Humidity9am    Humidity3pm  \
# count  143693.000000  142398.000000  142806.000000  140953.000000
# mean       14.043426      18.662657      68.880831      51.539116
# std         8.915375       8.809800      19.029164      20.795902
# min         0.000000       0.000000       0.000000       0.000000
# ...

# %%
data.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall WindGustDir  WindGustSpeed  \
# 0  2008-12-01   Albury     13.4     22.9       0.6           W           44.0
# 1  2008-12-02   Albury      7.4     25.1       0.0         WNW           44.0
# 2  2008-12-03   Albury     12.9     25.7       0.0         WSW           46.0
# 3  2008-12-04   Albury      9.2     28.0       0.0          NE           24.0
# 4  2008-12-05   Albury     17.5     32.3       1.0           W           41.0
#
#   WindDir9am WindDir3pm  WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  \
# 0          W        WNW          20.0          24.0         71.0         22.0
# 1        NNW        WSW           4.0          22.0         44.0         25.0
# 2          W        WSW          19.0          26.0         38.0         30.0
# 3         SE          E          11.0           9.0         45.0         16.0
# 4        ENE         NW           7.0          20.0         82.0         33.0
#
# ...

# %%
data['RainToday'].replace({'No':0, 'Yes':1}, inplace=True)
data['RainTomorrow'].replace({'No':0, 'Yes':1}, inplace=True)

# %%
data.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall WindGustDir  WindGustSpeed  \
# 0  2008-12-01   Albury     13.4     22.9       0.6           W           44.0
# 1  2008-12-02   Albury      7.4     25.1       0.0         WNW           44.0
# 2  2008-12-03   Albury     12.9     25.7       0.0         WSW           46.0
# 3  2008-12-04   Albury      9.2     28.0       0.0          NE           24.0
# 4  2008-12-05   Albury     17.5     32.3       1.0           W           41.0
#
#   WindDir9am WindDir3pm  WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  \
# 0          W        WNW          20.0          24.0         71.0         22.0
# 1        NNW        WSW           4.0          22.0         44.0         25.0
# 2          W        WSW          19.0          26.0         38.0         30.0
# 3         SE          E          11.0           9.0         45.0         16.0
# 4        ENE         NW           7.0          20.0         82.0         33.0
#
# ...

# %%
data['Rainfall'] = data['Rainfall'].fillna((data['Rainfall'].mean))
data['WindGustDir'] = data['WindGustDir'].fillna((data['WindGustDir'].mean))
data['WindGustSpeed'] = data['WindGustSpeed'].fillna((data['WindGustSpeed'].mean))
data['WindDir9am'] = data['WindDir9am'].fillna((data['WindDir9am'].mean))
data['WindDir3pm'] = data['WindDir3pm'].fillna((data['WindDir3pm'].mean))
data['WindSpeed9am'] = data['WindSpeed9am'].fillna((data['WindSpeed9am'].mean))
data['WindSpeed3pm'] = data['WindSpeed3pm'].fillna((data['WindSpeed3pm'].mean))
data['Humidity9am'] = data['Humidity9am'].fillna((data['Humidity9am'].mean))
data['Humidity3pm'] = data['Humidity3pm'].fillna((data['Humidity3pm'].mean))
data['Pressure9am'] = data['Pressure9am'].fillna((data['Pressure9am'].mean))
data['Pressure3pm'] = data['Pressure3pm'].fillna((data['Pressure3pm'].mean))
data['Temp9am'] = data['Temp9am'].fillna((data['Temp9am'].mean))
data['Temp3pm'] = data['Temp3pm'].fillna((data['Temp3pm'].mean))
data['RainToday'] = data['RainToday'].fillna((data['RainToday'].mean))
data['RISK_MM'] = data['RISK_MM'].fillna((data['RISK_MM'].mean))
data['RainTomorrow'] = data['RainTomorrow'].fillna((data['RainTomorrow'].mean))
data['MinTemp'] = data['MinTemp'].fillna((data['MinTemp'].mean))
data['MaxTemp'] = data['MinTemp'].fillna((data['MinTemp'].mean))

# %%
np.sum(data.isnull())
# Out:
# MinTemp          0
# MaxTemp          0
# Rainfall         0
# WindGustSpeed    0
# WindSpeed9am     0
# WindSpeed3pm     0
# Humidity9am      0
# Humidity3pm      0
# Pressure9am      0
# Pressure3pm      0
# Temp9am          0
# Temp3pm          0
# RainToday        0
# RISK_MM          0
# RainTomorrow     0
# dtype: int64

# %%
from scipy import stats
data1 = data.drop(columns = ['Date','Location', 'WindGustDir', 'WindDir9am','WindDir3pm'])
z = np.abs(stats.zscore(data1._get_numeric_data())) #ini biar ngitung, tanpa variabel country
print(z)
data2 = data1[(z < 3).all(axis=1)] #melihat ukuran data setelah dihilangkan outlier
print(data2.shape)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-35-193c4b468b33> in <module>
#       1 from scipy import stats
# ----> 2 data1 = data.drop(columns = ['Date','Location', 'WindGustDir', 'WindDir9am','WindDir3pm'])
#       3 z = np.abs(stats.zscore(data1._get_numeric_data())) #ini biar ngitung, tanpa variabel country
#       4 print(z)
#       5 data2 = data1[(z < 3).all(axis=1)] #melihat ukuran data setelah dihilangkan outlier
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3695                                            index=index, columns=columns,
#    3696                                            level=level, inplace=inplace,
# -> 3697                                            errors=errors)
#    3698
#    3699     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# ...

# %%
from sklearn.preprocessing import normalize
datanorm = normalize(data, norm='l2') #default norm L2, other are L1 and max
datanorm = pd.DataFrame(xnorm)
datanorm.tail()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-78174fafac68> in <module>
#       1 from sklearn.preprocessing import normalize
# ----> 2 datanorm = normalize(data, norm='l2') #default norm L2, other are L1 and max
#       3 datanorm = pd.DataFrame(xnorm)
#       4 datanorm.tail()
#
# ~\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py in normalize(X, norm, axis, copy, return_norm)
#    1552
#    1553     X = check_array(X, sparse_format, copy=copy,
# -> 1554                     estimator='the normalize function', dtype=FLOAT_DTYPES)
#    1555     if axis == 0:
#    1556         X = X.T
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
# ...

# %%
from sklearn.feature_selection import SelectKBest, chi2
selector = SelectKBest(chi2, k="all")
X_new =selector.transform(Xx)
scores =selector.scores_
scores
